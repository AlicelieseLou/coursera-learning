# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 963us/sample - loss: 234.4872 - y1_output_loss: 109.8644 - y2_output_loss: 122.5817 - y1_output_root_mean_squared_error: 10.5284 - y2_output_root_mean_squared_error: 11.1194 - val_loss: 39.7638 - val_y1_output_loss: 20.7294 - val_y2_output_loss: 20.7995 - val_y1_output_root_mean_squared_error: 4.4118 - val_y2_output_root_mean_squared_error: 4.5055
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 28.9364 - y1_output_loss: 12.1730 - y2_output_loss: 16.4900 - y1_output_root_mean_squared_error: 3.5055 - y2_output_root_mean_squared_error: 4.0802 - val_loss: 32.9136 - val_y1_output_loss: 11.7762 - val_y2_output_loss: 20.9856 - val_y1_output_root_mean_squared_error: 3.3937 - val_y2_output_root_mean_squared_error: 4.6256
# Epoch 3/500
# 614/614 [==============================] - 0s 153us/sample - loss: 26.8372 - y1_output_loss: 10.3967 - y2_output_loss: 16.4951 - y1_output_root_mean_squared_error: 3.1993 - y2_output_root_mean_squared_error: 4.0745 - val_loss: 20.0970 - val_y1_output_loss: 9.4969 - val_y2_output_loss: 10.6141 - val_y1_output_root_mean_squared_error: 3.0576 - val_y2_output_root_mean_squared_error: 3.2785
# Epoch 4/500
# 614/614 [==============================] - 0s 147us/sample - loss: 24.3986 - y1_output_loss: 9.2976 - y2_output_loss: 15.1252 - y1_output_root_mean_squared_error: 3.0469 - y2_output_root_mean_squared_error: 3.8878 - val_loss: 34.3732 - val_y1_output_loss: 14.9390 - val_y2_output_loss: 20.0270 - val_y1_output_root_mean_squared_error: 3.7719 - val_y2_output_root_mean_squared_error: 4.4884
# Epoch 5/500
# 614/614 [==============================] - 0s 138us/sample - loss: 25.3043 - y1_output_loss: 9.3268 - y2_output_loss: 15.8133 - y1_output_root_mean_squared_error: 3.0656 - y2_output_root_mean_squared_error: 3.9883 - val_loss: 20.5407 - val_y1_output_loss: 9.4454 - val_y2_output_loss: 11.1637 - val_y1_output_root_mean_squared_error: 3.0197 - val_y2_output_root_mean_squared_error: 3.3797
# Epoch 6/500
# 614/614 [==============================] - 0s 138us/sample - loss: 24.5715 - y1_output_loss: 8.9529 - y2_output_loss: 15.6825 - y1_output_root_mean_squared_error: 2.9928 - y2_output_root_mean_squared_error: 3.9515 - val_loss: 53.8584 - val_y1_output_loss: 12.6533 - val_y2_output_loss: 41.6975 - val_y1_output_root_mean_squared_error: 3.4831 - val_y2_output_root_mean_squared_error: 6.4596
# Epoch 7/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.7516 - y1_output_loss: 8.5068 - y2_output_loss: 14.1087 - y1_output_root_mean_squared_error: 2.9218 - y2_output_root_mean_squared_error: 3.7702 - val_loss: 24.1227 - val_y1_output_loss: 11.3177 - val_y2_output_loss: 12.7140 - val_y1_output_root_mean_squared_error: 3.3257 - val_y2_output_root_mean_squared_error: 3.6142
# Epoch 8/500
# 614/614 [==============================] - 0s 137us/sample - loss: 22.6264 - y1_output_loss: 8.6542 - y2_output_loss: 14.2785 - y1_output_root_mean_squared_error: 2.9248 - y2_output_root_mean_squared_error: 3.7513 - val_loss: 18.3924 - val_y1_output_loss: 7.9713 - val_y2_output_loss: 10.3027 - val_y1_output_root_mean_squared_error: 2.8281 - val_y2_output_root_mean_squared_error: 3.2240
# Epoch 9/500
# 614/614 [==============================] - 0s 147us/sample - loss: 19.5719 - y1_output_loss: 7.7762 - y2_output_loss: 11.7139 - y1_output_root_mean_squared_error: 2.7943 - y2_output_root_mean_squared_error: 3.4298 - val_loss: 28.2534 - val_y1_output_loss: 10.6842 - val_y2_output_loss: 17.6995 - val_y1_output_root_mean_squared_error: 3.2066 - val_y2_output_root_mean_squared_error: 4.2392
# Epoch 10/500
# 614/614 [==============================] - 0s 140us/sample - loss: 20.5649 - y1_output_loss: 8.0270 - y2_output_loss: 12.5781 - y1_output_root_mean_squared_error: 2.8207 - y2_output_root_mean_squared_error: 3.5508 - val_loss: 28.1758 - val_y1_output_loss: 10.8927 - val_y2_output_loss: 17.7572 - val_y1_output_root_mean_squared_error: 3.2108 - val_y2_output_root_mean_squared_error: 4.2269
# Epoch 11/500
# 614/614 [==============================] - 0s 139us/sample - loss: 24.2867 - y1_output_loss: 8.5248 - y2_output_loss: 16.0105 - y1_output_root_mean_squared_error: 2.9120 - y2_output_root_mean_squared_error: 3.9758 - val_loss: 30.6697 - val_y1_output_loss: 9.7878 - val_y2_output_loss: 21.4922 - val_y1_output_root_mean_squared_error: 3.1145 - val_y2_output_root_mean_squared_error: 4.5793
# Epoch 12/500
# 614/614 [==============================] - 0s 144us/sample - loss: 18.3124 - y1_output_loss: 7.0051 - y2_output_loss: 11.1745 - y1_output_root_mean_squared_error: 2.6570 - y2_output_root_mean_squared_error: 3.3545 - val_loss: 16.3814 - val_y1_output_loss: 7.4518 - val_y2_output_loss: 8.7176 - val_y1_output_root_mean_squared_error: 2.7436 - val_y2_output_root_mean_squared_error: 2.9755
# Epoch 13/500
# 614/614 [==============================] - 0s 145us/sample - loss: 19.2185 - y1_output_loss: 7.4276 - y2_output_loss: 11.7353 - y1_output_root_mean_squared_error: 2.7265 - y2_output_root_mean_squared_error: 3.4328 - val_loss: 14.5846 - val_y1_output_loss: 6.8725 - val_y2_output_loss: 7.4379 - val_y1_output_root_mean_squared_error: 2.6410 - val_y2_output_root_mean_squared_error: 2.7585
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.6010 - y1_output_loss: 6.5488 - y2_output_loss: 9.9669 - y1_output_root_mean_squared_error: 2.5699 - y2_output_root_mean_squared_error: 3.1617 - val_loss: 27.0712 - val_y1_output_loss: 8.1578 - val_y2_output_loss: 18.8929 - val_y1_output_root_mean_squared_error: 2.8111 - val_y2_output_root_mean_squared_error: 4.3782
# Epoch 15/500
# 614/614 [==============================] - 0s 135us/sample - loss: 16.1075 - y1_output_loss: 6.3141 - y2_output_loss: 9.6562 - y1_output_root_mean_squared_error: 2.5247 - y2_output_root_mean_squared_error: 3.1199 - val_loss: 23.9031 - val_y1_output_loss: 8.3252 - val_y2_output_loss: 16.0371 - val_y1_output_root_mean_squared_error: 2.8933 - val_y2_output_root_mean_squared_error: 3.9411
# Epoch 16/500
# 614/614 [==============================] - 0s 142us/sample - loss: 18.0121 - y1_output_loss: 6.4561 - y2_output_loss: 11.4018 - y1_output_root_mean_squared_error: 2.5508 - y2_output_root_mean_squared_error: 3.3920 - val_loss: 18.2896 - val_y1_output_loss: 6.5998 - val_y2_output_loss: 11.2695 - val_y1_output_root_mean_squared_error: 2.5727 - val_y2_output_root_mean_squared_error: 3.4163
# Epoch 17/500
# 614/614 [==============================] - 0s 134us/sample - loss: 18.2281 - y1_output_loss: 6.4504 - y2_output_loss: 11.7611 - y1_output_root_mean_squared_error: 2.5467 - y2_output_root_mean_squared_error: 3.4267 - val_loss: 41.7949 - val_y1_output_loss: 12.0561 - val_y2_output_loss: 29.5330 - val_y1_output_root_mean_squared_error: 3.4336 - val_y2_output_root_mean_squared_error: 5.4777
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.0816 - y1_output_loss: 5.7822 - y2_output_loss: 9.3638 - y1_output_root_mean_squared_error: 2.3984 - y2_output_root_mean_squared_error: 3.0544 - val_loss: 19.9809 - val_y1_output_loss: 8.1106 - val_y2_output_loss: 11.6999 - val_y1_output_root_mean_squared_error: 2.8169 - val_y2_output_root_mean_squared_error: 3.4707
# Epoch 19/500
# 614/614 [==============================] - 0s 144us/sample - loss: 15.9478 - y1_output_loss: 5.7257 - y2_output_loss: 10.1375 - y1_output_root_mean_squared_error: 2.4006 - y2_output_root_mean_squared_error: 3.1914 - val_loss: 11.1524 - val_y1_output_loss: 5.0558 - val_y2_output_loss: 5.8946 - val_y1_output_root_mean_squared_error: 2.2633 - val_y2_output_root_mean_squared_error: 2.4556
# Epoch 20/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.5769 - y1_output_loss: 5.8020 - y2_output_loss: 10.6288 - y1_output_root_mean_squared_error: 2.4188 - y2_output_root_mean_squared_error: 3.2751 - val_loss: 12.4631 - val_y1_output_loss: 5.3674 - val_y2_output_loss: 6.8909 - val_y1_output_root_mean_squared_error: 2.3278 - val_y2_output_root_mean_squared_error: 2.6542
# Epoch 21/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.6681 - y1_output_loss: 5.2142 - y2_output_loss: 8.3954 - y1_output_root_mean_squared_error: 2.2870 - y2_output_root_mean_squared_error: 2.9048 - val_loss: 18.5878 - val_y1_output_loss: 7.1976 - val_y2_output_loss: 11.6200 - val_y1_output_root_mean_squared_error: 2.6036 - val_y2_output_root_mean_squared_error: 3.4365
# Epoch 22/500
# 614/614 [==============================] - 0s 149us/sample - loss: 12.6638 - y1_output_loss: 4.9898 - y2_output_loss: 7.6759 - y1_output_root_mean_squared_error: 2.2307 - y2_output_root_mean_squared_error: 2.7727 - val_loss: 13.8042 - val_y1_output_loss: 5.2231 - val_y2_output_loss: 8.5486 - val_y1_output_root_mean_squared_error: 2.3191 - val_y2_output_root_mean_squared_error: 2.9028
# Epoch 23/500
# 614/614 [==============================] - 0s 138us/sample - loss: 14.4041 - y1_output_loss: 4.9736 - y2_output_loss: 9.3668 - y1_output_root_mean_squared_error: 2.2369 - y2_output_root_mean_squared_error: 3.0660 - val_loss: 12.3400 - val_y1_output_loss: 4.8877 - val_y2_output_loss: 7.2978 - val_y1_output_root_mean_squared_error: 2.1964 - val_y2_output_root_mean_squared_error: 2.7415
# Epoch 24/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.4636 - y1_output_loss: 4.8741 - y2_output_loss: 8.7118 - y1_output_root_mean_squared_error: 2.2113 - y2_output_root_mean_squared_error: 2.9281 - val_loss: 23.9045 - val_y1_output_loss: 5.5652 - val_y2_output_loss: 18.7361 - val_y1_output_root_mean_squared_error: 2.3535 - val_y2_output_root_mean_squared_error: 4.2855
# Epoch 25/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.5508 - y1_output_loss: 4.4521 - y2_output_loss: 8.0781 - y1_output_root_mean_squared_error: 2.1166 - y2_output_root_mean_squared_error: 2.8409 - val_loss: 44.6170 - val_y1_output_loss: 7.5915 - val_y2_output_loss: 38.5220 - val_y1_output_root_mean_squared_error: 2.7751 - val_y2_output_root_mean_squared_error: 6.0759
# Epoch 26/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.4389 - y1_output_loss: 5.1738 - y2_output_loss: 9.3117 - y1_output_root_mean_squared_error: 2.2774 - y2_output_root_mean_squared_error: 3.0418 - val_loss: 12.5887 - val_y1_output_loss: 5.8419 - val_y2_output_loss: 6.8186 - val_y1_output_root_mean_squared_error: 2.4138 - val_y2_output_root_mean_squared_error: 2.6004
# Epoch 27/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.5185 - y1_output_loss: 4.5023 - y2_output_loss: 8.5612 - y1_output_root_mean_squared_error: 2.1020 - y2_output_root_mean_squared_error: 2.8460 - val_loss: 82.2822 - val_y1_output_loss: 20.2356 - val_y2_output_loss: 63.8746 - val_y1_output_root_mean_squared_error: 4.3690 - val_y2_output_root_mean_squared_error: 7.9495
# Epoch 28/500
# 614/614 [==============================] - 0s 147us/sample - loss: 14.1379 - y1_output_loss: 4.7343 - y2_output_loss: 9.5137 - y1_output_root_mean_squared_error: 2.1584 - y2_output_root_mean_squared_error: 3.0788 - val_loss: 20.7768 - val_y1_output_loss: 5.8620 - val_y2_output_loss: 14.4759 - val_y1_output_root_mean_squared_error: 2.4234 - val_y2_output_root_mean_squared_error: 3.8605
# Epoch 29/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.6852 - y1_output_loss: 4.0294 - y2_output_loss: 7.5659 - y1_output_root_mean_squared_error: 2.0162 - y2_output_root_mean_squared_error: 2.7604 - val_loss: 8.3409 - val_y1_output_loss: 3.2594 - val_y2_output_loss: 5.0121 - val_y1_output_root_mean_squared_error: 1.8188 - val_y2_output_root_mean_squared_error: 2.2434
# Epoch 30/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.7066 - y1_output_loss: 3.4214 - y2_output_loss: 6.2983 - y1_output_root_mean_squared_error: 1.8508 - y2_output_root_mean_squared_error: 2.5062 - val_loss: 11.1438 - val_y1_output_loss: 4.1786 - val_y2_output_loss: 6.7914 - val_y1_output_root_mean_squared_error: 2.0342 - val_y2_output_root_mean_squared_error: 2.6468
# Epoch 31/500
# 614/614 [==============================] - 0s 137us/sample - loss: 11.0001 - y1_output_loss: 3.7531 - y2_output_loss: 7.3432 - y1_output_root_mean_squared_error: 1.9221 - y2_output_root_mean_squared_error: 2.7029 - val_loss: 13.7371 - val_y1_output_loss: 4.3400 - val_y2_output_loss: 9.4375 - val_y1_output_root_mean_squared_error: 2.0297 - val_y2_output_root_mean_squared_error: 3.1012
# Epoch 32/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.0933 - y1_output_loss: 3.6603 - y2_output_loss: 6.4551 - y1_output_root_mean_squared_error: 1.8987 - y2_output_root_mean_squared_error: 2.5472 - val_loss: 8.4141 - val_y1_output_loss: 2.7326 - val_y2_output_loss: 5.5071 - val_y1_output_root_mean_squared_error: 1.6601 - val_y2_output_root_mean_squared_error: 2.3787
# Epoch 33/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.8113 - y1_output_loss: 2.9193 - y2_output_loss: 5.8266 - y1_output_root_mean_squared_error: 1.7117 - y2_output_root_mean_squared_error: 2.4252 - val_loss: 7.6029 - val_y1_output_loss: 3.0539 - val_y2_output_loss: 4.4986 - val_y1_output_root_mean_squared_error: 1.7625 - val_y2_output_root_mean_squared_error: 2.1205
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 9.3594 - y1_output_loss: 3.2593 - y2_output_loss: 6.1584 - y1_output_root_mean_squared_error: 1.8043 - y2_output_root_mean_squared_error: 2.4706 - val_loss: 9.1442 - val_y1_output_loss: 3.5450 - val_y2_output_loss: 5.6773 - val_y1_output_root_mean_squared_error: 1.8985 - val_y2_output_root_mean_squared_error: 2.3537
# Epoch 35/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.1401 - y1_output_loss: 3.4853 - y2_output_loss: 6.6773 - y1_output_root_mean_squared_error: 1.8588 - y2_output_root_mean_squared_error: 2.5855 - val_loss: 9.1498 - val_y1_output_loss: 3.6273 - val_y2_output_loss: 5.4910 - val_y1_output_root_mean_squared_error: 1.9150 - val_y2_output_root_mean_squared_error: 2.3415
# Epoch 36/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.7905 - y1_output_loss: 3.0107 - y2_output_loss: 5.7263 - y1_output_root_mean_squared_error: 1.7419 - y2_output_root_mean_squared_error: 2.3992 - val_loss: 8.7639 - val_y1_output_loss: 3.0665 - val_y2_output_loss: 5.7418 - val_y1_output_root_mean_squared_error: 1.7671 - val_y2_output_root_mean_squared_error: 2.3752
# Epoch 37/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.9664 - y1_output_loss: 3.0142 - y2_output_loss: 5.9106 - y1_output_root_mean_squared_error: 1.7368 - y2_output_root_mean_squared_error: 2.4392 - val_loss: 7.6816 - val_y1_output_loss: 2.6941 - val_y2_output_loss: 4.8511 - val_y1_output_root_mean_squared_error: 1.6522 - val_y2_output_root_mean_squared_error: 2.2253
# Epoch 38/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.9959 - y1_output_loss: 2.8544 - y2_output_loss: 6.1470 - y1_output_root_mean_squared_error: 1.6861 - y2_output_root_mean_squared_error: 2.4805 - val_loss: 8.8750 - val_y1_output_loss: 3.1449 - val_y2_output_loss: 5.7610 - val_y1_output_root_mean_squared_error: 1.7281 - val_y2_output_root_mean_squared_error: 2.4267
# Epoch 39/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.5828 - y1_output_loss: 2.9434 - y2_output_loss: 5.5972 - y1_output_root_mean_squared_error: 1.7216 - y2_output_root_mean_squared_error: 2.3704 - val_loss: 15.1024 - val_y1_output_loss: 3.5615 - val_y2_output_loss: 12.0136 - val_y1_output_root_mean_squared_error: 1.9135 - val_y2_output_root_mean_squared_error: 3.3825
# Epoch 40/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.7127 - y1_output_loss: 2.8610 - y2_output_loss: 6.0609 - y1_output_root_mean_squared_error: 1.6567 - y2_output_root_mean_squared_error: 2.4430 - val_loss: 14.4242 - val_y1_output_loss: 5.0948 - val_y2_output_loss: 9.2151 - val_y1_output_root_mean_squared_error: 2.2279 - val_y2_output_root_mean_squared_error: 3.0758
# Epoch 41/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.9182 - y1_output_loss: 2.6743 - y2_output_loss: 5.3706 - y1_output_root_mean_squared_error: 1.6197 - y2_output_root_mean_squared_error: 2.3011 - val_loss: 45.2250 - val_y1_output_loss: 12.9253 - val_y2_output_loss: 32.7585 - val_y1_output_root_mean_squared_error: 3.5106 - val_y2_output_root_mean_squared_error: 5.7359
# Epoch 42/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.5771 - y1_output_loss: 2.4867 - y2_output_loss: 5.1620 - y1_output_root_mean_squared_error: 1.5725 - y2_output_root_mean_squared_error: 2.2593 - val_loss: 9.7031 - val_y1_output_loss: 2.6729 - val_y2_output_loss: 6.8844 - val_y1_output_root_mean_squared_error: 1.6249 - val_y2_output_root_mean_squared_error: 2.6576
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.3136 - y1_output_loss: 2.6708 - y2_output_loss: 5.7549 - y1_output_root_mean_squared_error: 1.6407 - y2_output_root_mean_squared_error: 2.3710 - val_loss: 66.0718 - val_y1_output_loss: 8.3806 - val_y2_output_loss: 59.4790 - val_y1_output_root_mean_squared_error: 2.9268 - val_y2_output_root_mean_squared_error: 7.5832
# Epoch 44/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.5981 - y1_output_loss: 2.7552 - y2_output_loss: 5.8159 - y1_output_root_mean_squared_error: 1.6619 - y2_output_root_mean_squared_error: 2.4158 - val_loss: 8.6449 - val_y1_output_loss: 2.8648 - val_y2_output_loss: 5.7207 - val_y1_output_root_mean_squared_error: 1.6775 - val_y2_output_root_mean_squared_error: 2.4147
# Epoch 45/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.6449 - y1_output_loss: 2.8492 - y2_output_loss: 5.7526 - y1_output_root_mean_squared_error: 1.6893 - y2_output_root_mean_squared_error: 2.4065 - val_loss: 10.3189 - val_y1_output_loss: 3.9063 - val_y2_output_loss: 6.4424 - val_y1_output_root_mean_squared_error: 1.9947 - val_y2_output_root_mean_squared_error: 2.5179
# Epoch 46/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.1543 - y1_output_loss: 2.3845 - y2_output_loss: 4.7470 - y1_output_root_mean_squared_error: 1.5379 - y2_output_root_mean_squared_error: 2.1884 - val_loss: 10.4798 - val_y1_output_loss: 3.3801 - val_y2_output_loss: 7.0713 - val_y1_output_root_mean_squared_error: 1.8088 - val_y2_output_root_mean_squared_error: 2.6848
# Epoch 47/500
# 614/614 [==============================] - 0s 150us/sample - loss: 7.5836 - y1_output_loss: 2.4412 - y2_output_loss: 5.1636 - y1_output_root_mean_squared_error: 1.5613 - y2_output_root_mean_squared_error: 2.2685 - val_loss: 7.6179 - val_y1_output_loss: 3.0192 - val_y2_output_loss: 4.7379 - val_y1_output_root_mean_squared_error: 1.7626 - val_y2_output_root_mean_squared_error: 2.1240
# Epoch 48/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.3990 - y1_output_loss: 2.2516 - y2_output_loss: 5.1326 - y1_output_root_mean_squared_error: 1.5055 - y2_output_root_mean_squared_error: 2.2655 - val_loss: 6.8869 - val_y1_output_loss: 2.2607 - val_y2_output_loss: 4.8798 - val_y1_output_root_mean_squared_error: 1.4899 - val_y2_output_root_mean_squared_error: 2.1603
# Epoch 49/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.3309 - y1_output_loss: 2.8833 - y2_output_loss: 6.3929 - y1_output_root_mean_squared_error: 1.7033 - y2_output_root_mean_squared_error: 2.5357 - val_loss: 7.1420 - val_y1_output_loss: 2.5765 - val_y2_output_loss: 4.6631 - val_y1_output_root_mean_squared_error: 1.6172 - val_y2_output_root_mean_squared_error: 2.1276
# Epoch 50/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.5535 - y1_output_loss: 2.3194 - y2_output_loss: 5.2431 - y1_output_root_mean_squared_error: 1.5246 - y2_output_root_mean_squared_error: 2.2867 - val_loss: 9.6316 - val_y1_output_loss: 2.7035 - val_y2_output_loss: 6.6955 - val_y1_output_root_mean_squared_error: 1.6572 - val_y2_output_root_mean_squared_error: 2.6240
# Epoch 51/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.8494 - y1_output_loss: 2.2676 - y2_output_loss: 4.5495 - y1_output_root_mean_squared_error: 1.5109 - y2_output_root_mean_squared_error: 2.1369 - val_loss: 12.7615 - val_y1_output_loss: 3.2127 - val_y2_output_loss: 10.0160 - val_y1_output_root_mean_squared_error: 1.8170 - val_y2_output_root_mean_squared_error: 3.0757
# Epoch 52/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.3839 - y1_output_loss: 2.3203 - y2_output_loss: 5.0800 - y1_output_root_mean_squared_error: 1.5267 - y2_output_root_mean_squared_error: 2.2479 - val_loss: 19.6963 - val_y1_output_loss: 4.3858 - val_y2_output_loss: 16.2777 - val_y1_output_root_mean_squared_error: 2.1038 - val_y2_output_root_mean_squared_error: 3.9077
# Epoch 53/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.9666 - y1_output_loss: 2.3283 - y2_output_loss: 5.6485 - y1_output_root_mean_squared_error: 1.5304 - y2_output_root_mean_squared_error: 2.3716 - val_loss: 5.9753 - val_y1_output_loss: 1.9762 - val_y2_output_loss: 3.9790 - val_y1_output_root_mean_squared_error: 1.4062 - val_y2_output_root_mean_squared_error: 1.9995
# Epoch 54/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.7692 - y1_output_loss: 2.4403 - y2_output_loss: 5.3127 - y1_output_root_mean_squared_error: 1.5580 - y2_output_root_mean_squared_error: 2.3112 - val_loss: 9.7983 - val_y1_output_loss: 3.1295 - val_y2_output_loss: 6.7085 - val_y1_output_root_mean_squared_error: 1.7170 - val_y2_output_root_mean_squared_error: 2.6173
# Epoch 55/500
# 614/614 [==============================] - 0s 151us/sample - loss: 7.1154 - y1_output_loss: 1.9874 - y2_output_loss: 5.1033 - y1_output_root_mean_squared_error: 1.4126 - y2_output_root_mean_squared_error: 2.2628 - val_loss: 7.4568 - val_y1_output_loss: 2.4467 - val_y2_output_loss: 5.2663 - val_y1_output_root_mean_squared_error: 1.5729 - val_y2_output_root_mean_squared_error: 2.2322
# Epoch 56/500
# 614/614 [==============================] - 0s 152us/sample - loss: 6.7926 - y1_output_loss: 2.0390 - y2_output_loss: 4.7372 - y1_output_root_mean_squared_error: 1.4298 - y2_output_root_mean_squared_error: 2.1790 - val_loss: 5.6448 - val_y1_output_loss: 1.8628 - val_y2_output_loss: 3.8269 - val_y1_output_root_mean_squared_error: 1.3510 - val_y2_output_root_mean_squared_error: 1.9544
# Epoch 57/500
# 614/614 [==============================] - 0s 149us/sample - loss: 7.1880 - y1_output_loss: 2.0600 - y2_output_loss: 5.0931 - y1_output_root_mean_squared_error: 1.4386 - y2_output_root_mean_squared_error: 2.2624 - val_loss: 9.4589 - val_y1_output_loss: 3.2031 - val_y2_output_loss: 6.1447 - val_y1_output_root_mean_squared_error: 1.7761 - val_y2_output_root_mean_squared_error: 2.5109
# Epoch 58/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.2196 - y1_output_loss: 2.2426 - y2_output_loss: 4.9812 - y1_output_root_mean_squared_error: 1.4957 - y2_output_root_mean_squared_error: 2.2322 - val_loss: 6.7998 - val_y1_output_loss: 2.2118 - val_y2_output_loss: 4.6303 - val_y1_output_root_mean_squared_error: 1.4511 - val_y2_output_root_mean_squared_error: 2.1666
# Epoch 59/500
# 614/614 [==============================] - 0s 153us/sample - loss: 6.8871 - y1_output_loss: 1.9546 - y2_output_loss: 4.9460 - y1_output_root_mean_squared_error: 1.4030 - y2_output_root_mean_squared_error: 2.2178 - val_loss: 6.6727 - val_y1_output_loss: 2.2130 - val_y2_output_loss: 4.4193 - val_y1_output_root_mean_squared_error: 1.5036 - val_y2_output_root_mean_squared_error: 2.1004
# Epoch 60/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.1461 - y1_output_loss: 1.7923 - y2_output_loss: 4.3167 - y1_output_root_mean_squared_error: 1.3414 - y2_output_root_mean_squared_error: 2.0849 - val_loss: 6.3249 - val_y1_output_loss: 2.1935 - val_y2_output_loss: 4.1158 - val_y1_output_root_mean_squared_error: 1.4837 - val_y2_output_root_mean_squared_error: 2.0307
# Epoch 61/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.7934 - y1_output_loss: 1.7570 - y2_output_loss: 4.0001 - y1_output_root_mean_squared_error: 1.3267 - y2_output_root_mean_squared_error: 2.0083 - val_loss: 5.9588 - val_y1_output_loss: 2.2107 - val_y2_output_loss: 3.8461 - val_y1_output_root_mean_squared_error: 1.4972 - val_y2_output_root_mean_squared_error: 1.9280
# Epoch 62/500
# 614/614 [==============================] - 0s 152us/sample - loss: 5.7739 - y1_output_loss: 1.6162 - y2_output_loss: 4.1197 - y1_output_root_mean_squared_error: 1.2726 - y2_output_root_mean_squared_error: 2.0382 - val_loss: 4.9973 - val_y1_output_loss: 1.6737 - val_y2_output_loss: 3.4197 - val_y1_output_root_mean_squared_error: 1.2788 - val_y2_output_root_mean_squared_error: 1.8336
# Epoch 63/500
# 614/614 [==============================] - 0s 155us/sample - loss: 5.6883 - y1_output_loss: 1.6663 - y2_output_loss: 4.0119 - y1_output_root_mean_squared_error: 1.2955 - y2_output_root_mean_squared_error: 2.0025 - val_loss: 5.6416 - val_y1_output_loss: 1.4424 - val_y2_output_loss: 4.4803 - val_y1_output_root_mean_squared_error: 1.2079 - val_y2_output_root_mean_squared_error: 2.0451
# Epoch 64/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.9705 - y1_output_loss: 1.8537 - y2_output_loss: 5.1448 - y1_output_root_mean_squared_error: 1.3638 - y2_output_root_mean_squared_error: 2.2606 - val_loss: 5.0562 - val_y1_output_loss: 1.4787 - val_y2_output_loss: 3.7519 - val_y1_output_root_mean_squared_error: 1.2121 - val_y2_output_root_mean_squared_error: 1.8939
# Epoch 65/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.0212 - y1_output_loss: 1.5090 - y2_output_loss: 3.5318 - y1_output_root_mean_squared_error: 1.2304 - y2_output_root_mean_squared_error: 1.8728 - val_loss: 11.2992 - val_y1_output_loss: 2.1917 - val_y2_output_loss: 9.7504 - val_y1_output_root_mean_squared_error: 1.4915 - val_y2_output_root_mean_squared_error: 3.0124
# Epoch 66/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.1980 - y1_output_loss: 1.9928 - y2_output_loss: 5.1966 - y1_output_root_mean_squared_error: 1.4083 - y2_output_root_mean_squared_error: 2.2835 - val_loss: 36.1880 - val_y1_output_loss: 12.9182 - val_y2_output_loss: 23.6716 - val_y1_output_root_mean_squared_error: 3.6322 - val_y2_output_root_mean_squared_error: 4.7953
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6953 - y1_output_loss: 2.2073 - y2_output_loss: 5.4654 - y1_output_root_mean_squared_error: 1.4840 - y2_output_root_mean_squared_error: 2.3438 - val_loss: 9.4133 - val_y1_output_loss: 2.5497 - val_y2_output_loss: 7.1676 - val_y1_output_root_mean_squared_error: 1.6189 - val_y2_output_root_mean_squared_error: 2.6062
# Epoch 68/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.5092 - y1_output_loss: 1.3609 - y2_output_loss: 4.1153 - y1_output_root_mean_squared_error: 1.1652 - y2_output_root_mean_squared_error: 2.0375 - val_loss: 6.0538 - val_y1_output_loss: 2.4472 - val_y2_output_loss: 3.7629 - val_y1_output_root_mean_squared_error: 1.5046 - val_y2_output_root_mean_squared_error: 1.9468
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.1500 - y1_output_loss: 1.4806 - y2_output_loss: 3.6456 - y1_output_root_mean_squared_error: 1.2200 - y2_output_root_mean_squared_error: 1.9135 - val_loss: 4.8979 - val_y1_output_loss: 1.4510 - val_y2_output_loss: 3.4765 - val_y1_output_root_mean_squared_error: 1.1869 - val_y2_output_root_mean_squared_error: 1.8679
# Epoch 70/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.8577 - y1_output_loss: 1.7699 - y2_output_loss: 5.0470 - y1_output_root_mean_squared_error: 1.3350 - y2_output_root_mean_squared_error: 2.2529 - val_loss: 12.7625 - val_y1_output_loss: 3.3837 - val_y2_output_loss: 9.7591 - val_y1_output_root_mean_squared_error: 1.8726 - val_y2_output_root_mean_squared_error: 3.0424
# Epoch 71/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.5966 - y1_output_loss: 1.5979 - y2_output_loss: 4.0185 - y1_output_root_mean_squared_error: 1.2692 - y2_output_root_mean_squared_error: 1.9964 - val_loss: 7.6839 - val_y1_output_loss: 2.3987 - val_y2_output_loss: 5.6111 - val_y1_output_root_mean_squared_error: 1.5611 - val_y2_output_root_mean_squared_error: 2.2906
# Epoch 72/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.6237 - y1_output_loss: 1.2657 - y2_output_loss: 3.3380 - y1_output_root_mean_squared_error: 1.1274 - y2_output_root_mean_squared_error: 1.8310 - val_loss: 5.6670 - val_y1_output_loss: 1.5367 - val_y2_output_loss: 4.1091 - val_y1_output_root_mean_squared_error: 1.2082 - val_y2_output_root_mean_squared_error: 2.0512
# Epoch 73/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.9022 - y1_output_loss: 1.3786 - y2_output_loss: 3.5066 - y1_output_root_mean_squared_error: 1.1761 - y2_output_root_mean_squared_error: 1.8759 - val_loss: 9.7441 - val_y1_output_loss: 4.1304 - val_y2_output_loss: 5.4670 - val_y1_output_root_mean_squared_error: 2.0599 - val_y2_output_root_mean_squared_error: 2.3454
# Epoch 74/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.7857 - y1_output_loss: 1.7447 - y2_output_loss: 4.0037 - y1_output_root_mean_squared_error: 1.3229 - y2_output_root_mean_squared_error: 2.0089 - val_loss: 8.7571 - val_y1_output_loss: 2.7363 - val_y2_output_loss: 5.8994 - val_y1_output_root_mean_squared_error: 1.6347 - val_y2_output_root_mean_squared_error: 2.4668
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.0952 - y1_output_loss: 1.0866 - y2_output_loss: 3.0173 - y1_output_root_mean_squared_error: 1.0362 - y2_output_root_mean_squared_error: 1.7383 - val_loss: 4.6641 - val_y1_output_loss: 1.5325 - val_y2_output_loss: 3.1516 - val_y1_output_root_mean_squared_error: 1.2131 - val_y2_output_root_mean_squared_error: 1.7867
# Epoch 76/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.1066 - y1_output_loss: 1.0920 - y2_output_loss: 3.0141 - y1_output_root_mean_squared_error: 1.0370 - y2_output_root_mean_squared_error: 1.7410 - val_loss: 18.1656 - val_y1_output_loss: 6.0598 - val_y2_output_loss: 11.7432 - val_y1_output_root_mean_squared_error: 2.4573 - val_y2_output_root_mean_squared_error: 3.4824
# Epoch 77/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.2516 - y1_output_loss: 1.0219 - y2_output_loss: 3.2076 - y1_output_root_mean_squared_error: 1.0144 - y2_output_root_mean_squared_error: 1.7951 - val_loss: 4.7460 - val_y1_output_loss: 1.0898 - val_y2_output_loss: 3.8785 - val_y1_output_root_mean_squared_error: 1.0532 - val_y2_output_root_mean_squared_error: 1.9071
# Epoch 78/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.7685 - y1_output_loss: 1.1965 - y2_output_loss: 3.5843 - y1_output_root_mean_squared_error: 1.0951 - y2_output_root_mean_squared_error: 1.8893 - val_loss: 3.5887 - val_y1_output_loss: 1.0372 - val_y2_output_loss: 2.6281 - val_y1_output_root_mean_squared_error: 1.0108 - val_y2_output_root_mean_squared_error: 1.6022
# Epoch 79/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.7449 - y1_output_loss: 0.9352 - y2_output_loss: 2.8027 - y1_output_root_mean_squared_error: 0.9697 - y2_output_root_mean_squared_error: 1.6747 - val_loss: 3.6054 - val_y1_output_loss: 0.8155 - val_y2_output_loss: 3.1070 - val_y1_output_root_mean_squared_error: 0.9092 - val_y2_output_root_mean_squared_error: 1.6670
# Epoch 80/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.9224 - y1_output_loss: 1.3661 - y2_output_loss: 3.5153 - y1_output_root_mean_squared_error: 1.1723 - y2_output_root_mean_squared_error: 1.8836 - val_loss: 3.8328 - val_y1_output_loss: 1.0049 - val_y2_output_loss: 2.9377 - val_y1_output_root_mean_squared_error: 1.0028 - val_y2_output_root_mean_squared_error: 1.6814
# Epoch 81/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.1175 - y1_output_loss: 2.2411 - y2_output_loss: 4.8538 - y1_output_root_mean_squared_error: 1.5005 - y2_output_root_mean_squared_error: 2.2059 - val_loss: 10.5608 - val_y1_output_loss: 3.1357 - val_y2_output_loss: 7.1899 - val_y1_output_root_mean_squared_error: 1.7736 - val_y2_output_root_mean_squared_error: 2.7231
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.6632 - y1_output_loss: 2.1026 - y2_output_loss: 5.5258 - y1_output_root_mean_squared_error: 1.4561 - y2_output_root_mean_squared_error: 2.3544 - val_loss: 3.7431 - val_y1_output_loss: 0.8967 - val_y2_output_loss: 2.8685 - val_y1_output_root_mean_squared_error: 0.9505 - val_y2_output_root_mean_squared_error: 1.6851
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.8226 - y1_output_loss: 1.2735 - y2_output_loss: 3.5559 - y1_output_root_mean_squared_error: 1.1269 - y2_output_root_mean_squared_error: 1.8848 - val_loss: 5.5156 - val_y1_output_loss: 1.8934 - val_y2_output_loss: 3.6956 - val_y1_output_root_mean_squared_error: 1.3940 - val_y2_output_root_mean_squared_error: 1.8901
# Epoch 84/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.8037 - y1_output_loss: 1.0185 - y2_output_loss: 2.7640 - y1_output_root_mean_squared_error: 1.0080 - y2_output_root_mean_squared_error: 1.6697 - val_loss: 3.9255 - val_y1_output_loss: 0.8839 - val_y2_output_loss: 3.0726 - val_y1_output_root_mean_squared_error: 0.9511 - val_y2_output_root_mean_squared_error: 1.7381
# Epoch 85/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.0361 - y1_output_loss: 0.9306 - y2_output_loss: 3.0997 - y1_output_root_mean_squared_error: 0.9679 - y2_output_root_mean_squared_error: 1.7605 - val_loss: 4.5670 - val_y1_output_loss: 1.4041 - val_y2_output_loss: 3.2400 - val_y1_output_root_mean_squared_error: 1.2041 - val_y2_output_root_mean_squared_error: 1.7655
# Epoch 86/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.4769 - y1_output_loss: 1.1668 - y2_output_loss: 3.3114 - y1_output_root_mean_squared_error: 1.0696 - y2_output_root_mean_squared_error: 1.8256 - val_loss: 7.2861 - val_y1_output_loss: 2.6697 - val_y2_output_loss: 4.7193 - val_y1_output_root_mean_squared_error: 1.5953 - val_y2_output_root_mean_squared_error: 2.1774
# Epoch 87/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.8217 - y1_output_loss: 0.9514 - y2_output_loss: 2.8422 - y1_output_root_mean_squared_error: 0.9760 - y2_output_root_mean_squared_error: 1.6938 - val_loss: 3.1827 - val_y1_output_loss: 0.8980 - val_y2_output_loss: 2.3854 - val_y1_output_root_mean_squared_error: 0.9307 - val_y2_output_root_mean_squared_error: 1.5220
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.3787 - y1_output_loss: 0.9330 - y2_output_loss: 2.4729 - y1_output_root_mean_squared_error: 0.9693 - y2_output_root_mean_squared_error: 1.5618 - val_loss: 4.4464 - val_y1_output_loss: 0.8768 - val_y2_output_loss: 3.8841 - val_y1_output_root_mean_squared_error: 0.9457 - val_y2_output_root_mean_squared_error: 1.8847
# Epoch 89/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.1035 - y1_output_loss: 0.9287 - y2_output_loss: 3.1976 - y1_output_root_mean_squared_error: 0.9663 - y2_output_root_mean_squared_error: 1.7804 - val_loss: 8.7503 - val_y1_output_loss: 2.0129 - val_y2_output_loss: 7.2276 - val_y1_output_root_mean_squared_error: 1.4367 - val_y2_output_root_mean_squared_error: 2.5858
# Epoch 90/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3630 - y1_output_loss: 0.8040 - y2_output_loss: 2.5467 - y1_output_root_mean_squared_error: 0.8999 - y2_output_root_mean_squared_error: 1.5979 - val_loss: 6.1969 - val_y1_output_loss: 1.7366 - val_y2_output_loss: 4.3968 - val_y1_output_root_mean_squared_error: 1.3105 - val_y2_output_root_mean_squared_error: 2.1165
# Epoch 91/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.0030 - y1_output_loss: 0.9177 - y2_output_loss: 3.1237 - y1_output_root_mean_squared_error: 0.9616 - y2_output_root_mean_squared_error: 1.7545 - val_loss: 7.9100 - val_y1_output_loss: 1.5612 - val_y2_output_loss: 6.2043 - val_y1_output_root_mean_squared_error: 1.2469 - val_y2_output_root_mean_squared_error: 2.5209
# Epoch 92/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.2630 - y1_output_loss: 0.8414 - y2_output_loss: 2.4096 - y1_output_root_mean_squared_error: 0.9186 - y2_output_root_mean_squared_error: 1.5554 - val_loss: 3.5056 - val_y1_output_loss: 0.8406 - val_y2_output_loss: 3.0020 - val_y1_output_root_mean_squared_error: 0.9248 - val_y2_output_root_mean_squared_error: 1.6280
# Epoch 93/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.8778 - y1_output_loss: 1.4037 - y2_output_loss: 3.4592 - y1_output_root_mean_squared_error: 1.1894 - y2_output_root_mean_squared_error: 1.8610 - val_loss: 3.9351 - val_y1_output_loss: 1.3583 - val_y2_output_loss: 2.6245 - val_y1_output_root_mean_squared_error: 1.1628 - val_y2_output_root_mean_squared_error: 1.6072
# Epoch 94/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.1317 - y1_output_loss: 1.1660 - y2_output_loss: 2.9325 - y1_output_root_mean_squared_error: 1.0846 - y2_output_root_mean_squared_error: 1.7191 - val_loss: 2.8712 - val_y1_output_loss: 0.8016 - val_y2_output_loss: 2.1669 - val_y1_output_root_mean_squared_error: 0.8809 - val_y2_output_root_mean_squared_error: 1.4475
# Epoch 95/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.8550 - y1_output_loss: 0.9085 - y2_output_loss: 2.9253 - y1_output_root_mean_squared_error: 0.9518 - y2_output_root_mean_squared_error: 1.7173 - val_loss: 4.2580 - val_y1_output_loss: 1.2525 - val_y2_output_loss: 3.2924 - val_y1_output_root_mean_squared_error: 1.1036 - val_y2_output_root_mean_squared_error: 1.7435
# Epoch 96/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0807 - y1_output_loss: 0.7967 - y2_output_loss: 2.2785 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.5126 - val_loss: 2.8661 - val_y1_output_loss: 0.6525 - val_y2_output_loss: 2.3883 - val_y1_output_root_mean_squared_error: 0.8134 - val_y2_output_root_mean_squared_error: 1.4848
# Epoch 97/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.9777 - y1_output_loss: 1.0116 - y2_output_loss: 2.9333 - y1_output_root_mean_squared_error: 1.0095 - y2_output_root_mean_squared_error: 1.7201 - val_loss: 3.5276 - val_y1_output_loss: 0.9550 - val_y2_output_loss: 2.8070 - val_y1_output_root_mean_squared_error: 0.9896 - val_y2_output_root_mean_squared_error: 1.5963
# Epoch 98/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0921 - y1_output_loss: 0.8161 - y2_output_loss: 2.2607 - y1_output_root_mean_squared_error: 0.9056 - y2_output_root_mean_squared_error: 1.5073 - val_loss: 3.8782 - val_y1_output_loss: 1.2299 - val_y2_output_loss: 2.7842 - val_y1_output_root_mean_squared_error: 1.1025 - val_y2_output_root_mean_squared_error: 1.6318
# Epoch 99/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.7734 - y1_output_loss: 1.2425 - y2_output_loss: 3.5329 - y1_output_root_mean_squared_error: 1.1191 - y2_output_root_mean_squared_error: 1.8764 - val_loss: 13.1943 - val_y1_output_loss: 1.7972 - val_y2_output_loss: 12.1016 - val_y1_output_root_mean_squared_error: 1.3645 - val_y2_output_root_mean_squared_error: 3.3664
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5193 - y1_output_loss: 0.8292 - y2_output_loss: 2.7108 - y1_output_root_mean_squared_error: 0.9050 - y2_output_root_mean_squared_error: 1.6432 - val_loss: 3.8424 - val_y1_output_loss: 1.0596 - val_y2_output_loss: 2.8255 - val_y1_output_root_mean_squared_error: 1.0156 - val_y2_output_root_mean_squared_error: 1.6766
# Epoch 101/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4298 - y1_output_loss: 0.8614 - y2_output_loss: 2.5827 - y1_output_root_mean_squared_error: 0.9260 - y2_output_root_mean_squared_error: 1.6038 - val_loss: 2.9962 - val_y1_output_loss: 0.6794 - val_y2_output_loss: 2.5991 - val_y1_output_root_mean_squared_error: 0.8302 - val_y2_output_root_mean_squared_error: 1.5189
# Epoch 102/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0282 - y1_output_loss: 0.7533 - y2_output_loss: 2.2497 - y1_output_root_mean_squared_error: 0.8710 - y2_output_root_mean_squared_error: 1.5065 - val_loss: 4.2544 - val_y1_output_loss: 1.2092 - val_y2_output_loss: 3.1089 - val_y1_output_root_mean_squared_error: 1.0839 - val_y2_output_root_mean_squared_error: 1.7549
# Epoch 103/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.8965 - y1_output_loss: 0.9382 - y2_output_loss: 2.9341 - y1_output_root_mean_squared_error: 0.9712 - y2_output_root_mean_squared_error: 1.7185 - val_loss: 5.4377 - val_y1_output_loss: 2.3888 - val_y2_output_loss: 3.3192 - val_y1_output_root_mean_squared_error: 1.5604 - val_y2_output_root_mean_squared_error: 1.7329
# Epoch 104/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.3441 - y1_output_loss: 0.9267 - y2_output_loss: 2.3984 - y1_output_root_mean_squared_error: 0.9661 - y2_output_root_mean_squared_error: 1.5527 - val_loss: 3.7688 - val_y1_output_loss: 0.9808 - val_y2_output_loss: 2.8800 - val_y1_output_root_mean_squared_error: 0.9810 - val_y2_output_root_mean_squared_error: 1.6752
# Epoch 105/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8204 - y1_output_loss: 1.2823 - y2_output_loss: 3.6042 - y1_output_root_mean_squared_error: 1.1334 - y2_output_root_mean_squared_error: 1.8804 - val_loss: 8.7283 - val_y1_output_loss: 1.6115 - val_y2_output_loss: 7.7983 - val_y1_output_root_mean_squared_error: 1.2714 - val_y2_output_root_mean_squared_error: 2.6668
# Epoch 106/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.6817 - y1_output_loss: 0.9747 - y2_output_loss: 2.6807 - y1_output_root_mean_squared_error: 0.9916 - y2_output_root_mean_squared_error: 1.6427 - val_loss: 2.6523 - val_y1_output_loss: 0.6495 - val_y2_output_loss: 2.2418 - val_y1_output_root_mean_squared_error: 0.8169 - val_y2_output_root_mean_squared_error: 1.4089
# Epoch 107/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9612 - y1_output_loss: 0.7637 - y2_output_loss: 2.2144 - y1_output_root_mean_squared_error: 0.8745 - y2_output_root_mean_squared_error: 1.4820 - val_loss: 6.6154 - val_y1_output_loss: 0.6679 - val_y2_output_loss: 6.7369 - val_y1_output_root_mean_squared_error: 0.8198 - val_y2_output_root_mean_squared_error: 2.4379
# Epoch 108/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.6139 - y1_output_loss: 1.3509 - y2_output_loss: 4.2470 - y1_output_root_mean_squared_error: 1.1651 - y2_output_root_mean_squared_error: 2.0631 - val_loss: 4.6586 - val_y1_output_loss: 1.5069 - val_y2_output_loss: 3.3468 - val_y1_output_root_mean_squared_error: 1.2483 - val_y2_output_root_mean_squared_error: 1.7608
# Epoch 109/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.5547 - y1_output_loss: 1.1013 - y2_output_loss: 2.4399 - y1_output_root_mean_squared_error: 1.0515 - y2_output_root_mean_squared_error: 1.5650 - val_loss: 5.1798 - val_y1_output_loss: 1.6371 - val_y2_output_loss: 3.5565 - val_y1_output_root_mean_squared_error: 1.2723 - val_y2_output_root_mean_squared_error: 1.8871
# Epoch 110/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3726 - y1_output_loss: 0.9292 - y2_output_loss: 2.4274 - y1_output_root_mean_squared_error: 0.9649 - y2_output_root_mean_squared_error: 1.5626 - val_loss: 2.4463 - val_y1_output_loss: 0.5211 - val_y2_output_loss: 2.0482 - val_y1_output_root_mean_squared_error: 0.7311 - val_y2_output_root_mean_squared_error: 1.3827
# Epoch 111/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.6044 - y1_output_loss: 0.5573 - y2_output_loss: 2.0413 - y1_output_root_mean_squared_error: 0.7442 - y2_output_root_mean_squared_error: 1.4320 - val_loss: 3.2446 - val_y1_output_loss: 1.3513 - val_y2_output_loss: 2.0935 - val_y1_output_root_mean_squared_error: 1.1332 - val_y2_output_root_mean_squared_error: 1.4002
# Epoch 112/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7725 - y1_output_loss: 0.6909 - y2_output_loss: 2.0579 - y1_output_root_mean_squared_error: 0.8342 - y2_output_root_mean_squared_error: 1.4410 - val_loss: 2.5149 - val_y1_output_loss: 0.6019 - val_y2_output_loss: 2.0511 - val_y1_output_root_mean_squared_error: 0.7683 - val_y2_output_root_mean_squared_error: 1.3873
# Epoch 113/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.7240 - y1_output_loss: 0.6189 - y2_output_loss: 2.0972 - y1_output_root_mean_squared_error: 0.7815 - y2_output_root_mean_squared_error: 1.4537 - val_loss: 3.5919 - val_y1_output_loss: 0.7914 - val_y2_output_loss: 2.8264 - val_y1_output_root_mean_squared_error: 0.8955 - val_y2_output_root_mean_squared_error: 1.6703
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5415 - y1_output_loss: 0.6386 - y2_output_loss: 1.8904 - y1_output_root_mean_squared_error: 0.7995 - y2_output_root_mean_squared_error: 1.3792 - val_loss: 3.0811 - val_y1_output_loss: 0.7704 - val_y2_output_loss: 2.4300 - val_y1_output_root_mean_squared_error: 0.8700 - val_y2_output_root_mean_squared_error: 1.5246
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6241 - y1_output_loss: 0.6453 - y2_output_loss: 1.9979 - y1_output_root_mean_squared_error: 0.7989 - y2_output_root_mean_squared_error: 1.4092 - val_loss: 10.0204 - val_y1_output_loss: 2.5196 - val_y2_output_loss: 7.3367 - val_y1_output_root_mean_squared_error: 1.5858 - val_y2_output_root_mean_squared_error: 2.7396
# Epoch 116/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.5504 - y1_output_loss: 0.8023 - y2_output_loss: 2.7393 - y1_output_root_mean_squared_error: 0.8987 - y2_output_root_mean_squared_error: 1.6561 - val_loss: 3.8194 - val_y1_output_loss: 0.8097 - val_y2_output_loss: 3.4473 - val_y1_output_root_mean_squared_error: 0.9090 - val_y2_output_root_mean_squared_error: 1.7301
# Epoch 117/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.4040 - y1_output_loss: 0.6156 - y2_output_loss: 1.7954 - y1_output_root_mean_squared_error: 0.7820 - y2_output_root_mean_squared_error: 1.3388 - val_loss: 3.0739 - val_y1_output_loss: 0.9619 - val_y2_output_loss: 2.3081 - val_y1_output_root_mean_squared_error: 0.9820 - val_y2_output_root_mean_squared_error: 1.4524
# Epoch 118/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.5857 - y1_output_loss: 0.6387 - y2_output_loss: 1.9619 - y1_output_root_mean_squared_error: 0.7992 - y2_output_root_mean_squared_error: 1.3954 - val_loss: 3.9980 - val_y1_output_loss: 0.6061 - val_y2_output_loss: 3.4164 - val_y1_output_root_mean_squared_error: 0.7692 - val_y2_output_root_mean_squared_error: 1.8456
# Epoch 119/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6473 - y1_output_loss: 0.6332 - y2_output_loss: 2.0328 - y1_output_root_mean_squared_error: 0.7983 - y2_output_root_mean_squared_error: 1.4177 - val_loss: 3.6301 - val_y1_output_loss: 0.6688 - val_y2_output_loss: 3.3234 - val_y1_output_root_mean_squared_error: 0.8287 - val_y2_output_root_mean_squared_error: 1.7156
# Epoch 120/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.9432 - y1_output_loss: 1.5204 - y2_output_loss: 3.3895 - y1_output_root_mean_squared_error: 1.2383 - y2_output_root_mean_squared_error: 1.8466 - val_loss: 3.2772 - val_y1_output_loss: 0.5447 - val_y2_output_loss: 3.1650 - val_y1_output_root_mean_squared_error: 0.7440 - val_y2_output_root_mean_squared_error: 1.6504
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4545 - y1_output_loss: 0.1497 - y2_output_loss: 0.3052 - y1_output_root_mean_squared_error: 0.3875 - y2_output_root_mean_squared_error: 0.5517 - val_loss: 1.3270 - val_y1_output_loss: 0.2087 - val_y2_output_loss: 1.2630 - val_y1_output_root_mean_squared_error: 0.4580 - val_y2_output_root_mean_squared_error: 1.0570
# Epoch 462/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.8262 - y1_output_loss: 0.1932 - y2_output_loss: 0.6280 - y1_output_root_mean_squared_error: 0.4410 - y2_output_root_mean_squared_error: 0.7949 - val_loss: 1.2502 - val_y1_output_loss: 0.2087 - val_y2_output_loss: 1.1228 - val_y1_output_root_mean_squared_error: 0.4598 - val_y2_output_root_mean_squared_error: 1.0192
# Epoch 463/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4567 - y1_output_loss: 0.1273 - y2_output_loss: 0.3273 - y1_output_root_mean_squared_error: 0.3576 - y2_output_root_mean_squared_error: 0.5734 - val_loss: 1.0924 - val_y1_output_loss: 0.1869 - val_y2_output_loss: 0.9138 - val_y1_output_root_mean_squared_error: 0.4349 - val_y2_output_root_mean_squared_error: 0.9504
# Epoch 464/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4184 - y1_output_loss: 0.1426 - y2_output_loss: 0.2728 - y1_output_root_mean_squared_error: 0.3789 - y2_output_root_mean_squared_error: 0.5242 - val_loss: 0.9632 - val_y1_output_loss: 0.1889 - val_y2_output_loss: 0.8120 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 0.8796
# Epoch 465/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.6739 - y1_output_loss: 0.1715 - y2_output_loss: 0.4983 - y1_output_root_mean_squared_error: 0.4151 - y2_output_root_mean_squared_error: 0.7082 - val_loss: 0.9920 - val_y1_output_loss: 0.1880 - val_y2_output_loss: 0.8782 - val_y1_output_root_mean_squared_error: 0.4340 - val_y2_output_root_mean_squared_error: 0.8965
# Epoch 466/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3636 - y1_output_loss: 0.1137 - y2_output_loss: 0.2494 - y1_output_root_mean_squared_error: 0.3367 - y2_output_root_mean_squared_error: 0.5003 - val_loss: 1.0771 - val_y1_output_loss: 0.2976 - val_y2_output_loss: 0.7998 - val_y1_output_root_mean_squared_error: 0.5528 - val_y2_output_root_mean_squared_error: 0.8784
# Epoch 467/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3709 - y1_output_loss: 0.1259 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.4940 - val_loss: 0.9002 - val_y1_output_loss: 0.1550 - val_y2_output_loss: 0.7593 - val_y1_output_root_mean_squared_error: 0.3967 - val_y2_output_root_mean_squared_error: 0.8619
# Epoch 468/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4555 - y1_output_loss: 0.1548 - y2_output_loss: 0.3043 - y1_output_root_mean_squared_error: 0.3939 - y2_output_root_mean_squared_error: 0.5480 - val_loss: 1.4074 - val_y1_output_loss: 0.2497 - val_y2_output_loss: 1.1435 - val_y1_output_root_mean_squared_error: 0.5077 - val_y2_output_root_mean_squared_error: 1.0722
# Epoch 469/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.5754 - y1_output_loss: 0.1625 - y2_output_loss: 0.4169 - y1_output_root_mean_squared_error: 0.4044 - y2_output_root_mean_squared_error: 0.6418 - val_loss: 1.9696 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 1.7514 - val_y1_output_root_mean_squared_error: 0.4487 - val_y2_output_root_mean_squared_error: 1.3298
# Epoch 470/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4938 - y1_output_loss: 0.1583 - y2_output_loss: 0.3353 - y1_output_root_mean_squared_error: 0.3969 - y2_output_root_mean_squared_error: 0.5799 - val_loss: 1.0070 - val_y1_output_loss: 0.2174 - val_y2_output_loss: 0.8177 - val_y1_output_root_mean_squared_error: 0.4730 - val_y2_output_root_mean_squared_error: 0.8850
# Epoch 471/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3103 - y1_output_loss: 0.1165 - y2_output_loss: 0.1945 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.4393 - val_loss: 0.9111 - val_y1_output_loss: 0.1590 - val_y2_output_loss: 0.7734 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.8665
# Epoch 472/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.8015 - y1_output_loss: 0.2222 - y2_output_loss: 0.5753 - y1_output_root_mean_squared_error: 0.4727 - y2_output_root_mean_squared_error: 0.7603 - val_loss: 1.0700 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.9841 - val_y1_output_root_mean_squared_error: 0.4414 - val_y2_output_root_mean_squared_error: 0.9355
# Epoch 473/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4435 - y1_output_loss: 0.1266 - y2_output_loss: 0.3160 - y1_output_root_mean_squared_error: 0.3560 - y2_output_root_mean_squared_error: 0.5628 - val_loss: 0.9105 - val_y1_output_loss: 0.1725 - val_y2_output_loss: 0.7702 - val_y1_output_root_mean_squared_error: 0.4194 - val_y2_output_root_mean_squared_error: 0.8571
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4933 - y1_output_loss: 0.1663 - y2_output_loss: 0.3260 - y1_output_root_mean_squared_error: 0.4084 - y2_output_root_mean_squared_error: 0.5715 - val_loss: 1.2836 - val_y1_output_loss: 0.2541 - val_y2_output_loss: 1.0986 - val_y1_output_root_mean_squared_error: 0.5122 - val_y2_output_root_mean_squared_error: 1.0106
# Epoch 475/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3233 - y1_output_loss: 0.1190 - y2_output_loss: 0.2029 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.4516 - val_loss: 0.9128 - val_y1_output_loss: 0.1502 - val_y2_output_loss: 0.7968 - val_y1_output_root_mean_squared_error: 0.3863 - val_y2_output_root_mean_squared_error: 0.8738
# Epoch 476/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.0398 - y1_output_loss: 0.2753 - y2_output_loss: 0.7641 - y1_output_root_mean_squared_error: 0.5249 - y2_output_root_mean_squared_error: 0.8743 - val_loss: 4.7059 - val_y1_output_loss: 0.9607 - val_y2_output_loss: 3.8137 - val_y1_output_root_mean_squared_error: 0.9683 - val_y2_output_root_mean_squared_error: 1.9412
# Epoch 477/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.6534 - y1_output_loss: 0.1883 - y2_output_loss: 0.4613 - y1_output_root_mean_squared_error: 0.4356 - y2_output_root_mean_squared_error: 0.6809 - val_loss: 1.0772 - val_y1_output_loss: 0.1965 - val_y2_output_loss: 0.9376 - val_y1_output_root_mean_squared_error: 0.4460 - val_y2_output_root_mean_squared_error: 0.9371
# Epoch 478/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4618 - y1_output_loss: 0.1483 - y2_output_loss: 0.3127 - y1_output_root_mean_squared_error: 0.3851 - y2_output_root_mean_squared_error: 0.5599 - val_loss: 1.3017 - val_y1_output_loss: 0.1563 - val_y2_output_loss: 1.1358 - val_y1_output_root_mean_squared_error: 0.3965 - val_y2_output_root_mean_squared_error: 1.0698
# Epoch 479/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3117 - y1_output_loss: 0.1105 - y2_output_loss: 0.2037 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4476 - val_loss: 1.3227 - val_y1_output_loss: 0.1501 - val_y2_output_loss: 1.2687 - val_y1_output_root_mean_squared_error: 0.3900 - val_y2_output_root_mean_squared_error: 1.0819
# Epoch 480/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.4112 - y1_output_loss: 0.1221 - y2_output_loss: 0.2960 - y1_output_root_mean_squared_error: 0.3443 - y2_output_root_mean_squared_error: 0.5409 - val_loss: 0.9384 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.7527 - val_y1_output_root_mean_squared_error: 0.4486 - val_y2_output_root_mean_squared_error: 0.8586
# Epoch 481/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4813 - y1_output_loss: 0.1429 - y2_output_loss: 0.3362 - y1_output_root_mean_squared_error: 0.3793 - y2_output_root_mean_squared_error: 0.5809 - val_loss: 0.9223 - val_y1_output_loss: 0.2349 - val_y2_output_loss: 0.7082 - val_y1_output_root_mean_squared_error: 0.4871 - val_y2_output_root_mean_squared_error: 0.8277
# Epoch 482/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3207 - y1_output_loss: 0.1095 - y2_output_loss: 0.2098 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.4595 - val_loss: 0.9980 - val_y1_output_loss: 0.1583 - val_y2_output_loss: 0.8388 - val_y1_output_root_mean_squared_error: 0.3989 - val_y2_output_root_mean_squared_error: 0.9159
# Epoch 483/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3698 - y1_output_loss: 0.1210 - y2_output_loss: 0.2464 - y1_output_root_mean_squared_error: 0.3491 - y2_output_root_mean_squared_error: 0.4979 - val_loss: 0.8860 - val_y1_output_loss: 0.1846 - val_y2_output_loss: 0.7404 - val_y1_output_root_mean_squared_error: 0.4332 - val_y2_output_root_mean_squared_error: 0.8357
# Epoch 484/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3590 - y1_output_loss: 0.1269 - y2_output_loss: 0.2313 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.4817 - val_loss: 1.1124 - val_y1_output_loss: 0.2777 - val_y2_output_loss: 0.8892 - val_y1_output_root_mean_squared_error: 0.5322 - val_y2_output_root_mean_squared_error: 0.9106
# Epoch 485/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3655 - y1_output_loss: 0.1312 - y2_output_loss: 0.2327 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.4841 - val_loss: 0.9119 - val_y1_output_loss: 0.1619 - val_y2_output_loss: 0.7883 - val_y1_output_root_mean_squared_error: 0.4017 - val_y2_output_root_mean_squared_error: 0.8664
# Epoch 486/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3549 - y1_output_loss: 0.1208 - y2_output_loss: 0.2339 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.4843 - val_loss: 0.8985 - val_y1_output_loss: 0.1719 - val_y2_output_loss: 0.7565 - val_y1_output_root_mean_squared_error: 0.4170 - val_y2_output_root_mean_squared_error: 0.8512
# Epoch 487/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4606 - y1_output_loss: 0.1415 - y2_output_loss: 0.3155 - y1_output_root_mean_squared_error: 0.3771 - y2_output_root_mean_squared_error: 0.5642 - val_loss: 0.9915 - val_y1_output_loss: 0.2331 - val_y2_output_loss: 0.8118 - val_y1_output_root_mean_squared_error: 0.4869 - val_y2_output_root_mean_squared_error: 0.8685
# Epoch 488/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3583 - y1_output_loss: 0.1196 - y2_output_loss: 0.2360 - y1_output_root_mean_squared_error: 0.3470 - y2_output_root_mean_squared_error: 0.4878 - val_loss: 0.8477 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.6991 - val_y1_output_root_mean_squared_error: 0.4286 - val_y2_output_root_mean_squared_error: 0.8148
# Epoch 489/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5215 - y1_output_loss: 0.1491 - y2_output_loss: 0.3687 - y1_output_root_mean_squared_error: 0.3874 - y2_output_root_mean_squared_error: 0.6094 - val_loss: 0.8141 - val_y1_output_loss: 0.1499 - val_y2_output_loss: 0.7091 - val_y1_output_root_mean_squared_error: 0.3899 - val_y2_output_root_mean_squared_error: 0.8137
# Epoch 490/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.2974 - y1_output_loss: 0.1080 - y2_output_loss: 0.1898 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4344 - val_loss: 0.9366 - val_y1_output_loss: 0.1706 - val_y2_output_loss: 0.7916 - val_y1_output_root_mean_squared_error: 0.4189 - val_y2_output_root_mean_squared_error: 0.8724
# Epoch 491/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3106 - y1_output_loss: 0.1080 - y2_output_loss: 0.2040 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.4521 - val_loss: 1.4514 - val_y1_output_loss: 0.4769 - val_y2_output_loss: 1.0024 - val_y1_output_root_mean_squared_error: 0.6861 - val_y2_output_root_mean_squared_error: 0.9903
# Epoch 492/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3012 - y1_output_loss: 0.1061 - y2_output_loss: 0.1926 - y1_output_root_mean_squared_error: 0.3271 - y2_output_root_mean_squared_error: 0.4407 - val_loss: 0.8672 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.6755 - val_y1_output_root_mean_squared_error: 0.4647 - val_y2_output_root_mean_squared_error: 0.8070
# Epoch 493/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4070 - y1_output_loss: 0.1248 - y2_output_loss: 0.2802 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.5304 - val_loss: 0.8661 - val_y1_output_loss: 0.1951 - val_y2_output_loss: 0.7066 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.8174
# Epoch 494/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4991 - y1_output_loss: 0.1406 - y2_output_loss: 0.3563 - y1_output_root_mean_squared_error: 0.3762 - y2_output_root_mean_squared_error: 0.5980 - val_loss: 1.0487 - val_y1_output_loss: 0.1908 - val_y2_output_loss: 0.9067 - val_y1_output_root_mean_squared_error: 0.4396 - val_y2_output_root_mean_squared_error: 0.9249
# Epoch 495/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3598 - y1_output_loss: 0.1134 - y2_output_loss: 0.2434 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.4954 - val_loss: 0.9597 - val_y1_output_loss: 0.1574 - val_y2_output_loss: 0.8312 - val_y1_output_root_mean_squared_error: 0.4013 - val_y2_output_root_mean_squared_error: 0.8937
# Epoch 496/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3176 - y1_output_loss: 0.1149 - y2_output_loss: 0.2007 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.4498 - val_loss: 0.8591 - val_y1_output_loss: 0.1605 - val_y2_output_loss: 0.7180 - val_y1_output_root_mean_squared_error: 0.4036 - val_y2_output_root_mean_squared_error: 0.8344
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3739 - y1_output_loss: 0.1537 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.3923 - y2_output_root_mean_squared_error: 0.4691 - val_loss: 0.8709 - val_y1_output_loss: 0.1678 - val_y2_output_loss: 0.7166 - val_y1_output_root_mean_squared_error: 0.4105 - val_y2_output_root_mean_squared_error: 0.8381
# Epoch 498/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3197 - y1_output_loss: 0.1162 - y2_output_loss: 0.2015 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4501 - val_loss: 0.9187 - val_y1_output_loss: 0.1868 - val_y2_output_loss: 0.7612 - val_y1_output_root_mean_squared_error: 0.4310 - val_y2_output_root_mean_squared_error: 0.8561
# Epoch 499/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3554 - y1_output_loss: 0.1171 - y2_output_loss: 0.2449 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.4880 - val_loss: 2.9736 - val_y1_output_loss: 0.5096 - val_y2_output_loss: 2.4788 - val_y1_output_root_mean_squared_error: 0.7052 - val_y2_output_root_mean_squared_error: 1.5736
# Epoch 500/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3934 - y1_output_loss: 0.1185 - y2_output_loss: 0.2759 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5249 - val_loss: 1.0451 - val_y1_output_loss: 0.1823 - val_y2_output_loss: 0.9040 - val_y1_output_root_mean_squared_error: 0.4273 - val_y2_output_root_mean_squared_error: 0.9287

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 660us/sample - loss: 1.0451 - y1_output_loss: 0.1853 - y2_output_loss: 0.8611 - y1_output_root_mean_squared_error: 0.4273 - y2_output_root_mean_squared_error: 0.9287
# Loss = 1.0451007942100623, Y1_loss = 0.18530476093292236, Y1_mse = 0.4273328185081482, Y2_loss = 0.8611129522323608, Y2_mse = 0.9287020564079285

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
